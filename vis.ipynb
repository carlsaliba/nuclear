# %%
import numpy as np

data1 = np.loadtxt("ENDF_B-VIII.1_LI-6(N,T)HE-4.txt")
data2 = np.loadtxt("ENDF_B-VIII.1_AU-197(N,G)AU-198.yaml")

# %%
print(data1.shape)
print(data2.shape)
# Out:
# (395, 2)
# (20330, 2)

# %% [markdown]
# # Train

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming your data is in a variable called 'data'
x = data2[:, 0]  # All rows, column 0
y = data2[:, 1]  # All rows, column 1

# Log-log plot
plt.figure(figsize=(10, 6))
plt.loglog(x, y, 'o-', alpha=0.7, markersize=1)
plt.xlabel('X (log scale)')
plt.ylabel('Y (log scale)')
plt.title('Log-Log Plot')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# # VALIDATION

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming your data is in a variable called 'data'
x = data1[:, 0]  # All rows, column 0
y = data1[:, 1]  # All rows, column 1

# Log-log plot
plt.figure(figsize=(10, 6))
plt.loglog(x, y, 'o-', alpha=0.7, markersize=4)
plt.xlabel('X (log scale)')
plt.ylabel('Y (log scale)')
plt.title('Log-Log Plot')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## LOGGING the data

# %%
data2 = np.loadtxt("ENDF_B-VIII.1_AU-197(N,G)AU-198.yaml")
data2=np.log(data2)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming your data is in a variable called 'data'
x = data2[:, 0]  # All rows, column 0
y = data2[:, 1]  # All rows, column 1

# Log-log plot
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'o-', alpha=0.7, markersize=1)
plt.xlabel('X (log scale)')
plt.ylabel('Y (log scale)')
plt.title('Log-Log Plot')
plt.grid(True, alpha=0.3)
plt.show()
